# %%
import tokenizer as tok
import numpy as np
import os

# %%
# hyperparameters

tokenizer_path = "vocab.pkl"
vocab_size = 2048
hidden_size = 512
seq_length = 128
n_heads = 4

# %%
with open('sonnets.txt', 'r') as file:
    data = file.read()

# %%
if not os.path.exists(tokenizer_path):
    vocab = tok.build_vocab(data, vocab_size)
    tok.save_tokenizer(vocab, tokenizer_path)
    print(f"built a new tokenizer at {tokenizer_path}")
else:
    vocab = tok.load_tokenizer(tokenizer_path)
    print(f"loading existing tokenizer from {tokenizer_path}")
# Out:
# loading existing tokenizer from vocab.pkl

# %%
text = "i am a monkey"
encoded = tok.encode(text, vocab, seq_length)
encoded = np.array(encoded).reshape(1, -1)

# %%
import model as nn

# %%
model = [
    nn.Embedding(vocab_size, hidden_size),
    nn.Linear(hidden_size, hidden_size),
    nn.SelfAttention(hidden_size, hidden_size//n_heads)
]

# %%
x = encoded
for layer in model:
    x = layer.forward(x)

# %%
x.shape
# Out:
# (1, 128, 128)

# %%
for layer in model[::-1]:
    x = layer.backward(x, 0.1)

# %%
x.shape
# Out:
# (1, 128)
